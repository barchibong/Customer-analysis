# %%
#Importing Libraries
import pandas as pd
import numpy as np
import os

# %%
#Combine the pickle files back into a single DataFrame:
# Initialize an empty list to hold the individual DataFrames from the pickle files
dfs = []

# %%
num_chunks = 5

# %%
# Load each pickle file and append its DataFrame to the list
for i in range(num_chunks):
    chunk_df = pd.read_pickle(f'chunk_{i}.pickle')
    dfs.append(chunk_df)

# %%
# Concatenate the DataFrames into a single DataFrame
combined_df = pd.concat(dfs, ignore_index=True)

# %%
ords_prods_merge = combined_df

# %%
ords_prods_merge.head()
# Out:
#    Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0             0           1  Chocolate Sandwich Cookies        61
# 1             0           1  Chocolate Sandwich Cookies        61
# 2             0           1  Chocolate Sandwich Cookies        61
# 3             0           1  Chocolate Sandwich Cookies        61
# 4             0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  Unnamed: 0_y  order_id  user_id eval_set  ...  \
# 0             19     5.8          1987   3139998      138    prior  ...
# 1             19     5.8          1989   1977647      138    prior  ...
# 2             19     5.8         11433    389851      709    prior  ...
# 3             19     5.8         12198    652770      764    prior  ...
# 4             19     5.8         12200   1813452      764    prior  ...
#
#    order_hour_of_day  days_since_prior_order  add_to_cart_order  reordered  \
# ...

# %%
#creating a subset
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 22)

# %%
df.head(10)
# Out:
#    Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0             0           1  Chocolate Sandwich Cookies        61
# 1             0           1  Chocolate Sandwich Cookies        61
# 2             0           1  Chocolate Sandwich Cookies        61
# 3             0           1  Chocolate Sandwich Cookies        61
# 4             0           1  Chocolate Sandwich Cookies        61
# 5             0           1  Chocolate Sandwich Cookies        61
# 6             0           1  Chocolate Sandwich Cookies        61
# 7             0           1  Chocolate Sandwich Cookies        61
# 8             0           1  Chocolate Sandwich Cookies        61
# 9             0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  Unnamed: 0_y  order_id  user_id eval_set  ...  \
# 0             19     5.8          1987   3139998      138    prior  ...
# 1             19     5.8          1989   1977647      138    prior  ...
# ...

# %%
df.groupby('product_name')

# %%
#aggregating mean of the order_number in the subset
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.577493
# 2                17.320781
# 3                16.084944
# 4                17.530458
# 5                14.763075
# 6                16.658449
# 7                17.031590
# 8                15.076662
# 9                15.447580
# 10               18.681852
# 11               15.467644
# 12               14.327957
# 13               16.548642
# 14               16.960241
# 15               16.121948
# 16               17.802028
# 17               15.593633
# 18               19.674252
# 19               16.899756
# 20               16.255442
# 21               25.535479

# %%
#Entire dataframe
df= ords_prods_merge

# %%
df.shape
# Out:
# (32406040, 22)

# %%
df.head()
# Out:
#    Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0             0           1  Chocolate Sandwich Cookies        61
# 1             0           1  Chocolate Sandwich Cookies        61
# 2             0           1  Chocolate Sandwich Cookies        61
# 3             0           1  Chocolate Sandwich Cookies        61
# 4             0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  Unnamed: 0_y  order_id  user_id eval_set  ...  \
# 0             19     5.8          1987   3139998      138    prior  ...
# 1             19     5.8          1989   1977647      138    prior  ...
# 2             19     5.8         11433    389851      709    prior  ...
# 3             19     5.8         12198    652770      764    prior  ...
# 4             19     5.8         12200   1813452      764    prior  ...
#
#    order_hour_of_day  days_since_prior_order  add_to_cart_order  reordered  \
# ...

# %%
#Aggregating mean of the order_number in the entire dataframe
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.213779
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.171106
# 12               15.887671
# 13               16.583536
# 14               16.771241
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %%
#The department with an ID of 4 (produce) in the subset has a mean of around 17. Conversely, the department with an ID of 17 (household), only has a mean of around 15. The insight I can glean from this, then, is that produce sells considerably more on average than household goods in the subset dataframe.
#The results from the entire dataframe differ from those of the subset as the mean of some order_number were higher in the subset than in the entire dataframe and vice versa.

# %%
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     15.457838
# 2     17.277920
# 3     17.170395
# 4     17.811403
# 5     15.213779
# 6     16.439806
# 7     17.225802
# 8     15.340650
# 9     15.895474
# 10    20.197148
# 11    16.171106
# 12    15.887671
# 13    16.583536
# 14    16.771241
# 15    16.165037
# 16    17.665606
# 17    15.694469
# 18    19.310397
# 19    17.177343
# 20    16.473447
# 21    22.902379
# Name: order_number, dtype: float64

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                15.457838   1  99
# 2                17.277920   1  99
# 3                17.170395   1  99
# 4                17.811403   1  99
# 5                15.213779   1  99
# 6                16.439806   1  99
# 7                17.225802   1  99
# 8                15.340650   1  99
# 9                15.895474   1  99
# 10               20.197148   1  99
# 11               16.171106   1  99
# 12               15.887671   1  99
# 13               16.583536   1  99
# 14               16.771241   1  99
# 15               16.165037   1  99
# 16               17.665606   1  99
# 17               15.694469   1  99
# 18               19.310397   1  99
# 19               17.177343   1  99
# 20               16.473447   1  99
# 21               22.902379   1  99

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
#     Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0              0           1  Chocolate Sandwich Cookies        61
# 1              0           1  Chocolate Sandwich Cookies        61
# 2              0           1  Chocolate Sandwich Cookies        61
# 3              0           1  Chocolate Sandwich Cookies        61
# 4              0           1  Chocolate Sandwich Cookies        61
# 5              0           1  Chocolate Sandwich Cookies        61
# 6              0           1  Chocolate Sandwich Cookies        61
# 7              0           1  Chocolate Sandwich Cookies        61
# 8              0           1  Chocolate Sandwich Cookies        61
# 9              0           1  Chocolate Sandwich Cookies        61
# 10             0           1  Chocolate Sandwich Cookies        61
# 11             0           1  Chocolate Sandwich Cookies        61
# 12             0           1  Chocolate Sandwich Cookies        61
# ...

# %%
ords_prods_merge.head(100)
# Out:
#     Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0              0           1  Chocolate Sandwich Cookies        61
# 1              0           1  Chocolate Sandwich Cookies        61
# 2              0           1  Chocolate Sandwich Cookies        61
# 3              0           1  Chocolate Sandwich Cookies        61
# 4              0           1  Chocolate Sandwich Cookies        61
# ..           ...         ...                         ...       ...
# 95             0           1  Chocolate Sandwich Cookies        61
# 96             0           1  Chocolate Sandwich Cookies        61
# 97             0           1  Chocolate Sandwich Cookies        61
# 98             0           1  Chocolate Sandwich Cookies        61
# 99             0           1  Chocolate Sandwich Cookies        61
#
#     department_id  prices  Unnamed: 0_y  order_id  user_id eval_set  ...  \
# 0              19     5.8          1987   3139998      138    prior  ...
# ...

# %%
#Creating a loyalty flag
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15877394
# Loyal customer      10284396
# New customer         6244250
# Name: count, dtype: int64

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0       138  Regular customer            28
# 1       138  Regular customer            30
# 2       709      New customer             2
# 3       764      New customer             1
# 4       764      New customer             3
# 5       777  Regular customer            16
# 6       825      New customer             3
# 7       910  Regular customer            12
# 8      1052  Regular customer            10
# 9      1052  Regular customer            15
# 10     1379      New customer             1
# 11     1480    Loyal customer            36
# 12     1480    Loyal customer            38
# 13     1480    Loyal customer            39
# 14     1494  Regular customer             6
# 15     1494  Regular customer             7
# 16     1494  Regular customer             9
# 17     1540  Regular customer             4
# 18     1540  Regular customer             5
# 19     1540  Regular customer             6
# ...

# %%
#Creating a spending flag
ords_prods_merge.loc[ords_prods_merge['prices'] < 10, 'spending_flag'] = 'Low spender'

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] >= 10,'spending_flag'] = 'High spender'

# %%
ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# spending_flag
# Low spender     21762105
# High spender    10643935
# Name: count, dtype: int64

# %%
ords_prods_merge[['user_id', 'spending_flag', 'order_number']].head(60)
# Out:
#     user_id spending_flag  order_number
# 0       138   Low spender            28
# 1       138   Low spender            30
# 2       709   Low spender             2
# 3       764   Low spender             1
# 4       764   Low spender             3
# 5       777   Low spender            16
# 6       825   Low spender             3
# 7       910   Low spender            12
# 8      1052   Low spender            10
# 9      1052   Low spender            15
# 10     1379   Low spender             1
# 11     1480   Low spender            36
# 12     1480   Low spender            38
# 13     1480   Low spender            39
# 14     1494   Low spender             6
# 15     1494   Low spender             7
# 16     1494   Low spender             9
# 17     1540   Low spender             4
# 18     1540   Low spender             5
# 19     1540   Low spender             6
# 20     1540   Low spender             7
# 21     1540   Low spender             8
# ...

# %%
num_chunks = 5

# %%
# Calculate the number of rows in each chunk
chunk_size = len(ords_prods_merge) // num_chunks

# %%
# Split the DataFrame into chunks
chunks = [ords_prods_merge[i:i+chunk_size] for i in range(0, len(ords_prods_merge), chunk_size)]

# %%
chunk_size
# Out:
# 6481208

# %%
import os

# %%
# Save each chunk as a pickle file
for i, chunk in enumerate(chunks):
 chunk.to_pickle(f'chunk_{i}.pickle')
